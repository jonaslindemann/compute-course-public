# %% [markdown]
# <a href="https://colab.research.google.com/github/jonaslindemann/compute-course-public/blob/master/general/2025/Introduction_to_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Plotting with Matplotlib

# %% [markdown]
# ## Reference material and examples

# %% [markdown]
# https://matplotlib.org/api/pyplot_summary.html
#
# https://matplotlib.org/users/tutorials.html

# %% [markdown]
# ## Using Matplotlib

# %% [markdown]
# The simplest way to use Matplotlib is through the **pyplot** module. Matplotlib is importedt using the following code:

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# # Simple plotting

# %% [markdown]
# The simplest way to plot a simple plot is to call the **plot()** function with a list of values. If you run in Spyder, you must also call the **show()** function for the plot window to be displayed. If you run Matplotlib from a Notebook, this will automatically be the plot.

# %%
plt.plot([1,5,3,4])
plt.show()

# %% [markdown]
# Use the show function to display the plot.

# %% [markdown]
# # Plot NumPy arrays

# %%
import numpy as np

# %% [markdown]
# To plot a function, we first create 2 arrays, one for x and one for y:

# %%
#x = np.arange(0.0, 2*np.pi, 0.1)
x = np.linspace(0.0, 2*np.pi, 50)
y = np.sin(x)
print(x)
print(y)
# Out:
# [0.         0.12822827 0.25645654 0.38468481 0.51291309 0.64114136
#  0.76936963 0.8975979  1.02582617 1.15405444 1.28228272 1.41051099
#  1.53873926 1.66696753 1.7951958  1.92342407 2.05165235 2.17988062
#  2.30810889 2.43633716 2.56456543 2.6927937  2.82102197 2.94925025
#  3.07747852 3.20570679 3.33393506 3.46216333 3.5903916  3.71861988
#  3.84684815 3.97507642 4.10330469 4.23153296 4.35976123 4.48798951
#  4.61621778 4.74444605 4.87267432 5.00090259 5.12913086 5.25735913
#  5.38558741 5.51381568 5.64204395 5.77027222 5.89850049 6.02672876
#  6.15495704 6.28318531]
# [ 0.00000000e+00  1.27877162e-01  2.53654584e-01  3.75267005e-01
#   4.90717552e-01  5.98110530e-01  6.95682551e-01  7.81831482e-01
#   8.55142763e-01  9.14412623e-01  9.58667853e-01  9.87181783e-01
#   9.99486216e-01  9.95379113e-01  9.74927912e-01  9.38468422e-01
#   8.86599306e-01  8.20172255e-01  7.40277997e-01  6.48228395e-01
#   5.45534901e-01  4.33883739e-01  3.15108218e-01  1.91158629e-01
# ...

# %% [markdown]
# We plot the function by calling **plot()** with arrays x and y:

# %%
plt.plot(x, y)
plt.show()

# %% [markdown]
# # Changing the line type

# %% [markdown]
# Use MATLAB's syntax to specify colors for series and dot properties.

# %%
plt.plot(x, y, 'ro')
plt.show()

# %%
plt.plot(x, y, 'bo-')
plt.show()

# %%
plt.plot(x, y, 'b--')
plt.show()

# %%
plt.plot(x, y, 'b+')
plt.show()

# %%
plt.plot(x, y, 'g+-')
plt.show()

# %% [markdown]
# ---
# # Short assignment
#
# Plot the function $ f(x) = sin(x) + sin(3x)/3 + sin(5x)/5 $ using a blue line. Use the np.linspace() function to create an array of x-values. Create the y values using an array expression. Don't forget to prefix the math functions with np.

# %% [markdown]
# ---

# %% [markdown]
# # Multiple series in the same plot

# %%
x = np.linspace(0.0, 2*np.pi, 50)
y1 = np.sin(x)
y2 = np.cos(x)

# %% [markdown]
# Multiple series can be plotted simultaneously by adding them to the **plot()** function argument.

# %%
plt.plot(x, y1, 'r-', x, y2, 'b-')
plt.show()

# %% [markdown]
# # Change series properties

# %%
plt.plot(x, y1, 'r-', x, y2, 'b-', linewidth=4.0) # Ändra linjetjocklek för alla serier.
plt.show()

# %%
line1, line2 = plt.plot(x, y1, 'r-', x, y2, 'b-')
line1.set_linewidth(4.0)
line2.set_linewidth(8.0)
plt.show()

# %%
lines = plt.plot(x, y1, 'r-', x, y2, 'b-') # lines är en lista av Line2D-objekt
plt.setp(lines, linewidth = 8.0) # Sätter egenskaper för alla linjer i lines
plt.show()

# %% [markdown]
# # Plotting to multiple figure windows

# %% [markdown]
# Several figures can be created using the **figure()** function. Figures can be given numbers, so you can indicate to which figure is the active.

# %%
plt.figure(1)
plt.plot(x, y1, 'r-')

plt.figure(2)
plt.plot(x, y2, 'b-')

plt.show()

# %% [markdown]
# # Subplots

# %% [markdown]
# Often, plots must be combined into a single plot. This is done with the **subplots()** function. Arguments to the function is given by a special integer consisting of 3 numbers. The first numbers give the rows and columns for the plot. The last number indicates the ID of the subplot.
#
# 211 - [2x1] id = 1
#
# 212 - [2x1] id = 2

# %%
plt.figure(1)
plt.subplot(211) # Subplot med 2 rader, 1 kolumn och första plotten.
plt.plot(x, y1, 'r-')

plt.subplot(212)
plt.plot(x, y2, 'b-') # Subplot med 2 rader, 1 kolumn och andra plotten.

plt.show()

# %%
plt.figure(1)
plt.subplot(121) # Subplot med 1 rad, 2 kolumner och första plotten.
plt.plot(x, y1, 'r-')

plt.subplot(122)
plt.plot(x, y2, 'b-') # Subplot med 1 rad, 2 kolumner och andra plotten.

plt.show()

# %% [markdown]
# # Decorating plots - title and column headers

# %% [markdown]
# There are several ways of decorating plots in Matplotlib. All functions in Matplotlib work with the active figure. Switching between figures / subplots is done by using the functions **figure()** and **subplot()**.

# %%
plt.figure(1)
plt.subplot(211) # Byt till plot 211
plt.xlabel("x")
plt.ylabel("y1")
plt.plot(x, y1, 'r-')

plt.subplot(212) # Byt till plot 212
plt.xlabel("x")
plt.ylabel("y2")
plt.plot(x, y2, 'b-')

plt.show()

# %% [markdown]
# Text can be added to a chart using the **text()** function. The text is placed with the same coordinates as for the current plot. LaTeX commands can be used to display mathematical functions in the diagram.

# %%
plt.figure(1)
plt.xlabel("x")
plt.ylabel("y")
plt.text(np.pi/2, 0.8, r'$\sin(x=\frac{pi}{2})$', horizontalalignment='center')
plt.plot(x, y1, 'r-')
plt.show()

# %% [markdown]
# Adjusting text alignment is done using the argument *horizontalalignment* to **text()** function.

# %% [markdown]
# Annotations can be made using the **annotate()** function.

# %%
plt.figure(1)
plt.xlabel("x")
plt.ylabel("y")
plt.annotate('max', xy=(np.pi/2, 1), xytext=(np.pi/2, 0.0),
            arrowprops=dict(facecolor='black', shrink=0.1), horizontalalignment='center'
            )
plt.plot(x, y1, 'r-')

plt.show()

# %% [markdown]
# Axis boundaries can be set with the functions **xlim()** and **ylim()**:

# %%
plt.figure(1)
plt.xlabel("x")
plt.ylabel("y")
plt.xlim(0.0, np.pi)
plt.ylim(0.0, 1.0)
plt.annotate('max', xy=(np.pi/2, 1), xytext=(np.pi/2, 0.5),
            arrowprops=dict(facecolor='black', shrink=0.05),
            )
plt.plot(x, y1, 'r-')
plt.show()

# %% [markdown]
# The axis scales can be changed from linear to logarithmic using the **xscale()** and **yscale()** functions.

# %%
x = np.arange(0,2.0, 0.01)
y = np.exp(x)

plt.figure(1)
plt.yscale('log')
plt.xlabel("x")
plt.ylabel("y")
plt.plot(x, y, 'r-')

plt.show()

# %% [markdown]
# # More plot types

# %% [markdown]
# ## Histogram - hist()

# %%
np.random.seed(0)

# exempel data

mu = 100  # medelvärde för distributionen
sigma = 15  # standardavvikelse för distributionen

x = mu + sigma * np.random.randn(437)

num_bins = 20

plt.hist(x, num_bins, density=1)

plt.xlabel('Smarts')
plt.ylabel('Probability density')

plt.show()

# %% [markdown]
# ## Bar charts

# %%
np.random.seed(0)

# example data
x = np.arange(20)+1.0
y = np.random.rand(20)

plt.bar(x, y)
plt.xlim(0,21)
plt.xticks(range(1,20+1))

plt.show()

# %% [markdown]
# ## Scatter plots

# %%
for color in ['red', 'green', 'blue']:
    n = 200
    x, y = np.random.rand(2, n)
    scale = 200.0 * np.random.rand(n)
    plt.scatter(x, y, c=color, s=scale, label=color,
                alpha=0.3, edgecolors='none')

plt.legend()   # Lägger till en förklaring i diagrammet
plt.grid(True) # Anger att vi vill ha ett rutnät i diagrammet

plt.show()

# %% [markdown]
# ## Contour plots

# %%
N = 100

x = np.linspace(-6.0, 6.0, N)
y = np.linspace(-6.0, 6.0, N)

X, Y = np.meshgrid(x, y)

print(X)

Z = np.sin(0.5*X*Y)

print(Z)

plt.figure(1)
plt.contourf(X, Y, Z, cmap=plt.cm.RdBu) # cmap anger färgskala
plt.colorbar() # Lägger till en färgskala i plotten

plt.figure(2)
plt.contour(X, Y, Z, cmap=plt.cm.RdBu) # cmap anger färgskala
plt.colorbar() # Lägger till en färgskala i plotten

plt.show()
# Out:
# [[-6.         -5.87878788 -5.75757576 ...  5.75757576  5.87878788
#    6.        ]
#  [-6.         -5.87878788 -5.75757576 ...  5.75757576  5.87878788
#    6.        ]
#  [-6.         -5.87878788 -5.75757576 ...  5.75757576  5.87878788
#    6.        ]
#  ...
#  [-6.         -5.87878788 -5.75757576 ...  5.75757576  5.87878788
#    6.        ]
#  [-6.         -5.87878788 -5.75757576 ...  5.75757576  5.87878788
#    6.        ]
#  [-6.         -5.87878788 -5.75757576 ...  5.75757576  5.87878788
#    6.        ]]
# [[-0.75098725 -0.93673817 -0.99998181 ...  0.99998181  0.93673817
#    0.75098725]
#  [-0.93673817 -0.99999914 -0.93765472 ...  0.93765472  0.99999914
#    0.93673817]
#  [-0.99998181 -0.93765472 -0.76231079 ...  0.76231079  0.93765472
#    0.99998181]
#  ...
#  [ 0.99998181  0.93765472  0.76231079 ... -0.76231079 -0.93765472
#   -0.99998181]
#  [ 0.93673817  0.99999914  0.93765472 ... -0.93765472 -0.99999914
#   -0.93673817]
# ...

# %% [markdown]
# ## Displaying images

# %%
import urllib.request

urllib.request.urlretrieve('http://www.the8bitguy.com/wp-content/uploads/2018/04/A1_1.jpg', '6502.jpg')
# Out:
# ('6502.jpg', <http.client.HTTPMessage at 0x7fbc8c11ce50>)

# %%
image = plt.imread('6502.jpg')

plt.imshow(image)
plt.axis('on')  # ta bort axlarna
plt.show()

# %% [markdown]
# How the pixels should be softened or interpolated can also be controlled:

# %%
# from the docs:

# If interpolation is None, default to rc image.interpolation. See also
# the filternorm and filterrad parameters. If interpolation is 'none', then
# no interpolation is performed on the Agg, ps and pdf backends. Other
# backends will fall back to 'nearest'.
#
# http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.imshow

methods = [None, 'none', 'nearest', 'bilinear', 'bicubic', 'spline16',
           'spline36', 'hanning', 'hamming', 'hermite', 'kaiser', 'quadric',
           'catrom', 'gaussian', 'bessel', 'mitchell', 'sinc', 'lanczos']

np.random.seed(0)
grid = np.random.rand(4, 4)

fig, axes = plt.subplots(3, 6, figsize=(12, 6),
                         subplot_kw={'xticks': [], 'yticks': []})

fig.subplots_adjust(hspace=0.3, wspace=0.05)

for ax, interp_method in zip(axes.flat, methods):
    ax.imshow(grid, interpolation=interp_method, cmap='viridis')
    ax.set_title(interp_method)

plt.show()

# %% [markdown]
# ## Stream line plots

# %%
Y, X = np.mgrid[-3:3:100j, -3:3:100j]
U = -1 - X**2 + Y
V = 1 + X - Y**2
speed = np.sqrt(U*U + V*V)

fig0, ax0 = plt.subplots()
strm = ax0.streamplot(X, Y, U, V, color=U, linewidth=2, cmap=plt.cm.autumn)
fig0.colorbar(strm.lines)

fig1, (ax1, ax2) = plt.subplots(ncols=2)
ax1.streamplot(X, Y, U, V, density=[0.5, 1])

lw = 5*speed / speed.max()
ax2.streamplot(X, Y, U, V, density=0.6, color='k', linewidth=lw)

fig2, (ax3, ax4) = plt.subplots(ncols=2)
ax3.contourf(X, Y, U, cmap=plt.cm.RdBu)
ax4.contourf(X, Y, V, cmap=plt.cm.RdBu)

plt.show()

# %% [markdown]
# ## Bar charts

# %%
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]
explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()

#ax1.pie(sizes, labels=labels)

ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)

ax1.axis('equal')

plt.show()

# %%
N = 20
theta = np.linspace(0.0, 2 * np.pi, N, endpoint=False)
radii = 10 * np.random.rand(N)
width = np.pi / 4 * np.random.rand(N)

ax = plt.subplot(111, projection='polar')
bars = ax.bar(theta, radii, width=width, bottom=0.0)

for r, bar in zip(radii, bars):
    bar.set_facecolor(plt.cm.viridis(r / 10.))
    bar.set_alpha(0.5)

plt.show()

# %% [markdown]
# ## 3D plot

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
from matplotlib import cm

N = 100

x = np.linspace(-6.0, 6.0, N)
y = np.linspace(-6.0, 6.0, N)

X, Y = np.meshgrid(x, y)

z = np.sin(0.5*X*Y)

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, z, cmap=plt.cm.RdBu)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_zlim(-5, 5)
plt.show()
